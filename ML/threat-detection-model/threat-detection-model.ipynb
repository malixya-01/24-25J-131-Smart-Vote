# %%
# !pip install ultralytics
# !pip install --upgrade google-cloud-bigquery google-cloud-storage
# !pip install pandas==1.5.3
# !pip install pydantic==1.10.12
# !pip install -U ipywidgets
# !pip install --upgrade pandas
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 899.1/899.1 kB 14.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 240.1/240.1 kB 4.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 131.8/131.8 kB 11.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: google-cloud-storage
#     Found existing installation: google-cloud-storage 2.8.0
#     Uninstalling google-cloud-storage-2.8.0:
#       Successfully uninstalled google-cloud-storage-2.8.0
#   Attempting uninstall: google-cloud-bigquery
#     Found existing installation: google-cloud-bigquery 3.25.0
#     Uninstalling google-cloud-bigquery-3.25.0:
#       Successfully uninstalled google-cloud-bigquery-3.25.0
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.1/12.1 MB 98.8 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.2.2
#     Uninstalling pandas-2.2.2:
#       Successfully uninstalled pandas-2.2.2
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from ultralytics import YOLO

# Load the YOLOv8 nano model
model = YOLO('yolov8n.pt')
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# 100%|██████████| 6.25M/6.25M [00:00<00:00, 57.7MB/s]

# %%
data_path = '/content/drive/MyDrive/Research Project/Dataset/data.yaml'

# %%
results = model.train(data=data_path, epochs=20, imgsz=640, batch=16)
# Out:
# Ultralytics 8.3.41 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
import os

test_images_path = '/content/drive/MyDrive/Research Project/Dataset/test'
print("Directory exists:", os.path.exists(test_images_path))
print("Files in directory:", os.listdir(test_images_path))
# Out:
# Directory exists: True
# Files in directory: ['labels', 'images']

# %%
test_images = '/content/drive/MyDrive/Research Project/Dataset/test/images'

# %%
#prediction results
results2 = model.predict(source=test_images, conf=0.25, save=True, save_dir='runs/predict_test/')
# Out:
# image 1/97 /content/drive/MyDrive/Research Project/Dataset/test/images/armas-1063-_jpg.rf.12a1a4bb64d396f96bf93a3a9a50985e.jpg: 640x640 1 pistol, 28.1ms
# image 2/97 /content/drive/MyDrive/Research Project/Dataset/test/images/armas-1108-_jpg.rf.7485cf7f8176009ff6f079a0b09e12d7.jpg: 640x640 (no detections), 12.0ms
# image 3/97 /content/drive/MyDrive/Research Project/Dataset/test/images/armas-1110-_jpg.rf.14823fce22531c62ef0071cd89d11098.jpg: 640x640 1 pistol, 11.8ms
# image 4/97 /content/drive/MyDrive/Research Project/Dataset/test/images/armas-1114-_jpg.rf.8e8b5c19c81900fa7d4772e8ab687d64.jpg: 640x640 1 pistol, 11.7ms
# image 5/97 /content/drive/MyDrive/Research Project/Dataset/test/images/armas-114-_jpg.rf.6aaae3f93a8a4b319b9b82e1bf24e459.jpg: 640x640 (no detections), 11.6ms
# image 6/97 /content/drive/MyDrive/Research Project/Dataset/test/images/armas-1153-_jpg.rf.14a4727c651f81fef172b5eea3a02041.jpg: 640x640 2 pistols, 11.9ms
# ...

# %%
import cv2
from ultralytics import YOLO
import PIL
from PIL import Image
from IPython.display import display
import os
import pathlib

# %%
results1 = model.predict(source="/content/drive/MyDrive/Research Project/Dataset/test/images/armas-1206-_jpg.rf.77a40d80d803c83b978895da24883298.jpg",
              save=True, conf=0.2,iou=0.5)

Results = results1[0]
# Out:
# image 1/1 /content/drive/MyDrive/Research Project/Dataset/test/images/armas-1206-_jpg.rf.77a40d80d803c83b978895da24883298.jpg: 640x640 2 pistols, 34.0ms
# Speed: 4.8ms preprocess, 34.0ms inference, 6.5ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/train5

# %%
# Plotting results
plot = results1[0].plot()
plot = cv2.cvtColor(plot, cv2.COLOR_BGR2RGB)
display(Image.fromarray(plot))
# Out:
# <PIL.Image.Image image mode=RGB size=640x640>

# %%
results1 = model.predict(source="/content/drive/MyDrive/Research Project/Dataset/test/images/armas-1309-_jpg.rf.8d98fd0c66fbff14395f35dbd2ae6b3b.jpg",
              save=True, conf=0.2,iou=0.5)

Results = results1[0]
# Out:
# image 1/1 /content/drive/MyDrive/Research Project/Dataset/test/images/armas-1309-_jpg.rf.8d98fd0c66fbff14395f35dbd2ae6b3b.jpg: 640x640 2 pistols, 15.0ms
# Speed: 3.0ms preprocess, 15.0ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/train6

# %%
# Plotting results
plot = results1[0].plot()
plot = cv2.cvtColor(plot, cv2.COLOR_BGR2RGB)
display(Image.fromarray(plot))
# Out:
# <PIL.Image.Image image mode=RGB size=640x640>

# %%
results1 = model.predict(source="/content/drive/MyDrive/Research Project/Dataset/test/images/armas-1573-_jpg.rf.9552eafa7122e967aa2309fbeeaa4af1.jpg",
              save=True, conf=0.2,iou=0.5)

Results = results1[0]
# Out:
# image 1/1 /content/drive/MyDrive/Research Project/Dataset/test/images/armas-1573-_jpg.rf.9552eafa7122e967aa2309fbeeaa4af1.jpg: 640x640 3 pistols, 12.2ms
# Speed: 2.4ms preprocess, 12.2ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/train7

# %%
# Plotting results
plot = results1[0].plot()
plot = cv2.cvtColor(plot, cv2.COLOR_BGR2RGB)
display(Image.fromarray(plot))
# Out:
# <PIL.Image.Image image mode=RGB size=640x640>

# %%
results1 = model.predict(source="/content/drive/MyDrive/Research Project/Dataset/test/images/armas-957-_jpg.rf.33c41de44839588473c1b1c8d831a415.jpg",
              save=True, conf=0.2,iou=0.5)

Results = results1[0]
# Out:
# image 1/1 /content/drive/MyDrive/Research Project/Dataset/test/images/armas-957-_jpg.rf.33c41de44839588473c1b1c8d831a415.jpg: 640x640 1 pistol, 14.4ms
# Speed: 2.4ms preprocess, 14.4ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/train8

# %%
# Plotting results
plot = results1[0].plot()
plot = cv2.cvtColor(plot, cv2.COLOR_BGR2RGB)
display(Image.fromarray(plot))
# Out:
# <PIL.Image.Image image mode=RGB size=640x640>

# %%
results1 = model.predict(source="/content/drive/MyDrive/Research Project/Dataset/test/images/armas-235-_jpg.rf.6fc3ee23bb00e2501964f00875e22779.jpg",
              save=True, conf=0.2,iou=0.5)

Results = results1[0]

# %%
# Plotting results
plot = results1[0].plot()
plot = cv2.cvtColor(plot, cv2.COLOR_BGR2RGB)
display(Image.fromarray(plot))
